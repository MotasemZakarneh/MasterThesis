# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mplt
#for inset color bars

import JG_Helpers as jg

mplt.rcParams['figure.dpi'] = 300 #high res display

# %% [markdown]
# Functions Start

# %%
jg.visualize_network_2_in(weigths=[[
    [0.2, 0.9]  # weights of 2 input neurons for single output neuron
]],
    biases=[[0.5]  # bias for single output neuron
            ],
    activations=["sig"  # activation for output
                 ],
    y0range=[-3, 3], y1range=[-3, 3]
)
